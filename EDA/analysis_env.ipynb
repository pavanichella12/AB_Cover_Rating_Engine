# %% [markdown]
# # ABCover Analysis Environment
#
# Run this notebook to set up the analysis environment. Install dependencies first: `pip install -r requirements-notebook.txt`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print('Environment ready.')
